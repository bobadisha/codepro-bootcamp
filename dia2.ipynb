# %%
#challenge 6
marcas = ["Nissan", "Chrevrolet", "Toyota", "Ferrari"]
for palabra in marcas:
 if  len (palabra) >= 6:
    print(marcas)
# Out:
# ['Nissan', 'Chrevrolet', 'Toyota', 'Ferrari']
# ['Nissan', 'Chrevrolet', 'Toyota', 'Ferrari']
# ['Nissan', 'Chrevrolet', 'Toyota', 'Ferrari']
# ['Nissan', 'Chrevrolet', 'Toyota', 'Ferrari']

# %%
#challenge 5
for number in range(10):
    print(number * 2)

# %%
#challenge 4

lista_de_materias=["Matematica", "Ciencias", "Lenguas", "Orientacion", "Fisica"]
print("Lista Total")
print(lista_de_materias)

lista_de_materias.append("Quimica")
print("Agregamos nuevo elemento")
print(lista_de_materias)

lista_de_materias.remove("Lenguas")
print("Eliminamos el tercer elemento")
print(lista_de_materias )
# Out:
# Lista Total
# ['Matematica', 'Ciencias', 'Lenguas', 'Orientacion', 'Fisica']
# Agregamos nuevo elemento
# ['Matematica', 'Ciencias', 'Lenguas', 'Orientacion', 'Fisica', 'Quimica']
# Eliminamos el tercer elemento
# ['Matematica', 'Ciencias', 'Orientacion', 'Fisica', 'Quimica']

# %%
#challenge 2

temperatura = int(input('temperatura es'))
print(temperatura)

if temperatura <= -10 and temperatura >= 18:
    print("fesquete")
elif temperatura <= 19 and temperatura >= 30:
    print("calor'i'")
elif temperatura <= 31 and temperatura >= 45:
    print("hakuuuu")

else:
    print ("tamo frito")
# Out:
# 12
# tamo frito

# %%
temperatura = int(input('temperatura es'))
print(temperatura)

if -10 <= temperatura <= 18:
    print('fesquete')
elif 19 <= temperatura <= 30:
    print('haku')
elif 31 <= temperatura <= 45:
    print('hakuro')
else:
    print ('tamo frito')
# Out:
# 33
# hakuro
