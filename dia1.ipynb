# %%
#Challenge 5
#Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas

producto = 'Canon Eos R'

def caracteristicas():
    print('Estabilizacion Integrada')
    print('Enfoque automatico')
    print('Graba 8K')


print(f'Elemento seleccionado', producto)
caracteristicas()
# Out:
# Elemento seleccionado Canon Eos R
# Estabilizacion Integrada
# Enfoque automatico
# Graba 8K

# %%
#challenge 4
#Crear una funcion de un proceso que se les ocurra que tenga varios pasos. Ejecutar la funcion tres veces

def inicio_del_dia():
    print('* despertarse')
    print('* levantarse de la cama')
    print('* ir a ducharse')
    print('* salir a vestirse')
    print('* empezar las tareas')

print('Lunes')
inicio_del_dia()
print('Martes')
inicio_del_dia()
print('Miercoles')
inicio_del_dia()

print('REPETIR TODOS LOS DIAS!!!')
# Out:
# Lunes
# * despertarse
# * levantarse de la cama
# * ir a ducharse
# * salir a vestirse
# * empezar las tareas
# Martes
# * despertarse
# * levantarse de la cama
# * ir a ducharse
# * salir a vestirse
# * empezar las tareas
# Miercoles
# * despertarse
# * levantarse de la cama
# * ir a ducharse
# * salir a vestirse
# * empezar las tareas
# REPETIR TODOS LOS DIAS!!!

# %%
#challenge 3
#Solicitar al usuario ingresar dos numeros y almacenarlos en dos variables. Luego imprimir la suma de los dos

primer_dato = int(input('Escribe un numero al azar'))
segundo_dato = int( input('Escribe otro numero al azar'))
 
suma = primer_dato + segundo_dato
print(primer_dato, '+', segundo_dato,'=', suma)
# Out:
# 300 + 230 = 530

# %%
#challenge 3 
#Asignar el nombre del companhero a las variables nombre y apellido, luego imprimir una frase etc

nombre = 'Dua'
apellido = 'Lipa'

print('Hola yo soy', nombre, apellido, 'mucho gusto!')
# Out:
# Hola yo soy Dua Lipa mucho gusto!

# %%
#challenge 2
#Suma
cantidad_de_manzanas = 474
cantidad_de_naranjas = 334 
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas 
print('El resultado de la suma es', cantidad_de_frutas)

#Resta 
frutas_vendidas = 150 
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print('El resultado de la resta es', frutas_restantes)
# Out:
# El resultado de la suma es 808
# El resultado de la resta es 658

# %%
#challenge
nombre = 'Rafa'
edad = 26
ciudad = 'San Lorenzo City'

print( nombre, edad, ciudad)
# Out:
# Rafa 26 San Lorenzo City
